# %% [markdown]
# """БОЕВОЙ ОПЫТ решения неработающих плагинов VS CODE // Установка ИСХОДНИКОВ плагина."""

# %%
https://www.youtube.com/watch?v=-aCdtZ8qL24

Плагины для VS Code — это расширения

Основа: брать чужие плагины и переписывать при способности (знать JS)

# %% [markdown]
# в расширении переходим на ссылку гитхаб. Если он старый (например, последнее изменение 3 года), то через форк-view existing forks видим список тех, кто скопировал этот плагин(репозиторий) и дорабатывал, делал в нем недавние свежие изменения. У такого пользователя мы будем использовать расширение
#
# Устанавливаем плагин, который доработал самый крутой парень
# code - download ZIP - открываем в проводнике - вырезаем из него папку
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# "C:\Users\vikto\.vscode\extensions"
#
# вставляем плагин в список расширений (-main удаляем из названия - но иногда не надо)
# нерабочий удаляем
#
# как понять что это наш вставленный плагин в установленных расширениях в vscode? в папке README расширения написать что-то свое (например, вместо Links - SENATOROV AI).
#
# Перезапустить vscode. Находим - Enable
#
# НО он мог не закрыть дырку, которая нам нужно

# %% [markdown]
# Установка исходного плагина
#
# поиск по названию плагина в гитхаб (например, Jupytext)
#
# как понять, что это плагин для vscode? - по структуре: vscode.d.ts, icon.png, python-libs, images
#
# также скачиваем
# ![image.png](attachment:image.png) здесь список изменений, которые внес крутой чувак (files changed)
#
# если у найденного чувака была найдена в ишьюсах данная проблема, но не устранена, смотрим на тех, кто форкал его репозиторий и дорабатывал (форк-view existing forks)

# %% [markdown]
# при запуске нужно проверять зависимости
# ![image.png](attachment:image.png)
#
# Требование другой версии, подключение основ Jupyter и тд
